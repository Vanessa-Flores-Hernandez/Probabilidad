# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Flores-Hernandez/Probabilidad/blob/main/Unidad2/probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilida y estadistica**
#
# ## **Unidad 2**
#
# ### **Practica 3. Permutaciones**
#
# ### Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: Vanessa Mariam Flores Hernandez

# %%
import math as mt
from itertools import permutations

nombres = ["a1", "a2", "a3", "a4", "a5", "a6", "a7", "a8", "a9", "a10"]
n = len(nombres)
r = 4  # 4 como agrupar?

Pr = mt.factorial(n) / (mt.factorial(n - r))

print("Existen",Pr,"posibles permutaciones sin repetición del total de",n,"nombres en grupos de",r,"en",r,)

print("Aquí las permutaciones")
permutaciones_nombres = list(permutations(nombres, r))

# Imprime las permutaciones
for permutacion in permutaciones_nombres:
  print(permutacion)
# Out:
# Existen 5040.0 posibles permutaciones sin repetición del total de 10 nombres en grupos de 4 en 4
# Aquí las permutaciones
# ('a1', 'a2', 'a3', 'a4')
# ('a1', 'a2', 'a3', 'a5')
# ('a1', 'a2', 'a3', 'a6')
# ('a1', 'a2', 'a3', 'a7')
# ('a1', 'a2', 'a3', 'a8')
# ('a1', 'a2', 'a3', 'a9')
# ('a1', 'a2', 'a3', 'a10')
# ('a1', 'a2', 'a4', 'a3')
# ('a1', 'a2', 'a4', 'a5')
# ('a1', 'a2', 'a4', 'a6')
# ('a1', 'a2', 'a4', 'a7')
# ('a1', 'a2', 'a4', 'a8')
# ('a1', 'a2', 'a4', 'a9')
# ('a1', 'a2', 'a4', 'a10')
# ('a1', 'a2', 'a5', 'a3')
# ('a1', 'a2', 'a5', 'a4')
# ('a1', 'a2', 'a5', 'a6')
# ('a1', 'a2', 'a5', 'a7')
# ('a1', 'a2', 'a5', 'a8')
# ('a1', 'a2', 'a5', 'a9')
# ('a1', 'a2', 'a5', 'a10')
# ('a1', 'a2', 'a6', 'a3')
# ('a1', 'a2', 'a6', 'a4')
# ('a1', 'a2', 'a6', 'a5')
# ('a1', 'a2', 'a6', 'a7')
# ('a1', 'a2', 'a6', 'a8')
# ('a1', 'a2', 'a6', 'a9')
# ('a1', 'a2', 'a6', 'a10')
# ('a1', 'a2', 'a7', 'a3')
# ('a1', 'a2', 'a7', 'a4')
# ('a1', 'a2', 'a7', 'a5')
# ('a1', 'a2', 'a7', 'a6')
# ...
