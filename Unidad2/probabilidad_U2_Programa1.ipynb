# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Flores-Hernandez/Probabilidad/blob/main/Unidad2/probabilidad_U2_Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilida y estadistica**
#
# ## **Unidad 2**
#
# ### **Practica 1. Combinaciones sin repetición y con repetición**
#
# ### Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: Vanessa Mariam Flores Hernandez

# %%
import math as mt # Para utilizar factorial
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
nombres = ["Oscar", "Paco", "Paty", "Laura", "Ruben", "Luis", "Lucy", "Alberto", "Juan", "Juan", "Danny"]
n = len(nombres)
r = 2 # como agrupar?

Cn = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n-r))
print("Existen ", Cn , " posibles combinaciones sin repeticion del total de ",
      n , " nombres "," en grupos de ", r , " en ", r)

print("Aqui las combinaciones")
combinaciones_nombres = list(combinations(nombres,r))

#imprime las combinaciones
for combinacion in combinaciones_nombres:
    print(combinacion)
# Out:
# Existen  55.0  posibles combinaciones sin repeticion del total de  11  nombres   en grupos de  2  en  2
# Aqui las combinaciones
# ('Oscar', 'Paco')
# ('Oscar', 'Paty')
# ('Oscar', 'Laura')
# ('Oscar', 'Ruben')
# ('Oscar', 'Luis')
# ('Oscar', 'Lucy')
# ('Oscar', 'Alberto')
# ('Oscar', 'Juan')
# ('Oscar', 'Juan')
# ('Oscar', 'Danny')
# ('Paco', 'Paty')
# ('Paco', 'Laura')
# ('Paco', 'Ruben')
# ('Paco', 'Luis')
# ('Paco', 'Lucy')
# ('Paco', 'Alberto')
# ('Paco', 'Juan')
# ('Paco', 'Juan')
# ('Paco', 'Danny')
# ('Paty', 'Laura')
# ('Paty', 'Ruben')
# ('Paty', 'Luis')
# ('Paty', 'Lucy')
# ('Paty', 'Alberto')
# ('Paty', 'Juan')
# ('Paty', 'Juan')
# ('Paty', 'Danny')
# ('Laura', 'Ruben')
# ('Laura', 'Luis')
# ('Laura', 'Lucy')
# ('Laura', 'Alberto')
# ('Laura', 'Juan')
# ('Laura', 'Juan')
# ('Laura', 'Danny')
# ('Ruben', 'Luis')
# ('Ruben', 'Lucy')
# ('Ruben', 'Alberto')
# ('Ruben', 'Juan')
# ('Ruben', 'Juan')
# ('Ruben', 'Danny')
# ('Luis', 'Lucy')
# ('Luis', 'Alberto')
# ('Luis', 'Juan')
# ('Luis', 'Juan')
# ('Luis', 'Danny')
# ('Lucy', 'Alberto')
# ('Lucy', 'Juan')
# ('Lucy', 'Juan')
# ('Lucy', 'Danny')
# ('Alberto', 'Juan')
# ('Alberto', 'Juan')
# ('Alberto', 'Danny')
# ('Juan', 'Juan')
# ('Juan', 'Danny')
# ('Juan', 'Danny')

# %% [markdown]
# Ejemplo 2. Caracteres alfabéticos y dígitos

# %%
caracteres = ["A", "B", "C", "D", "E", "F", "0", "1", "2", "3", "4", "5"]
n = len(caracteres)
r = 10 # como agrupar?

Cn = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n-r))


print("Existen ", Cn , " posibles combinaciones sin repeticion del total de ", n ,
      " caracteres ", " en grupos de ", r, " en ", r)

print("Aqui las combinaciones")
combinaciones_caracteres = list(combinations(caracteres,r))

#imprime las combinaciones
for combinacion in combinaciones_caracteres:
    print(combinacion)
# Out:
# Existen  66.0  posibles combinaciones sin repeticion del total de  12  caracteres   en grupos de  10  en  10
# Aqui las combinaciones
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '2', '3')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '2', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '2', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '1', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '0', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '0', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '0', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '2', '3', '4')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '2', '3', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '2', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '1', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '0', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '2', '3', '4')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '2', '3', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '2', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '1', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '0', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'B', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '4')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '2', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '1', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '0', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', '0', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'C', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('A', 'D', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '4')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '2', '3', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '2', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '1', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '0', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', '0', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'F', '0', '1', '2', '3', '4', '5')
# ('B', 'C', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('B', 'D', 'E', 'F', '0', '1', '2', '3', '4', '5')
# ('C', 'D', 'E', 'F', '0', '1', '2', '3', '4', '5')

# %% [markdown]
# Combinaciones con repetición

# %%
dado = ["1", "2", "3", "4", "5", "6"]
n = len(dado)
r =2 # como agrupar?, de dos en dos porque hay dos dados

CnR = mt.factorial(n+r-1) / (mt.factorial(r) * mt.factorial((n+r-1)-r))
print("Existen ", CnR , " posibles combinaciones con repeticion del total de ",
      n , " caracteres "," en grupos de ", r , " en ", r)
print("Aqui las combinaciones con repeticiones de dos dados")

# definir el conjunto de elementos
elementos = [1, 2, 3, 4, 5, 6]

# numero de elementos a elegir en cada combinacion
r=2

#calcular las combinaciones con repeticion
combinaciones_dados = list(combinations_with_replacement(dado,r))

#imprime las combinaciones
for combinacion in combinaciones_dados:
    print(combinacion)
# Out:
# Existen  21.0  posibles combinaciones con repeticion del total de  6  caracteres   en grupos de  2  en  2
# Aqui las combinaciones con repeticiones de dos dados
# ('1', '1')
# ('1', '2')
# ('1', '3')
# ('1', '4')
# ('1', '5')
# ('1', '6')
# ('2', '2')
# ('2', '3')
# ('2', '4')
# ('2', '5')
# ('2', '6')
# ('3', '3')
# ('3', '4')
# ('3', '5')
# ('3', '6')
# ('4', '4')
# ('4', '5')
# ('4', '6')
# ('5', '5')
# ('5', '6')
# ('6', '6')
