# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Flores-Hernandez/Probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilida y estadistica**
#
# ## **Unidad 1**
#
# ### **Practica 3. Tabla de frecuencias y reglas de Sturges...**
#
# ### Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: Vanessa Mariam Flores Hernandez

# %%
# basado en el libro estadistica para administracion pagina 12
# creamos una lista vacia que representa la edad de 100 personas
import random
edades = []
# hacemos un ciclo para generar 100 numeros aleatorios que representen la edad de las personas
for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  # numero_aleatorio
  numero_aleatorio = random.randint( 18, 70)
  # agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [30, 69, 68, 45, 41, 25, 55, 28, 57, 31, 49, 56, 60, 35, 34, 69, 50, 33, 53, 70, 26, 18, 42, 59, 37, 67, 56, 46, 31, 62, 35, 45, 40, 26, 69, 30, 50, 37, 70, 18, 69, 21, 60, 47, 59, 29, 66, 28, 59, 41, 48, 53, 38, 23, 54, 48, 26, 67, 66, 58, 32, 63, 49, 58, 65, 19, 56, 43, 58, 63, 63, 59, 24, 22, 38, 23, 51, 63, 68, 41, 47, 19, 67, 63, 58, 24, 33, 26, 59, 52, 28, 70, 47, 69, 46, 63, 26, 52, 69, 35]

# %%
import pandas as pd

# %%
# crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns = ["Edad"])
df.head()
# Out:
#    Edad
# 0    30
# 1    69
# 2    68
# 3    45
# 4    41

# %%
# calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")

# imprimir la tabla de distribucion de frecuencias
print("Tabla de distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 21    18           2
# 16    19           2
# 38    21           1
# 44    22           1
# 25    23           2
# 14    24           2
# 32    25           1
# 2     26           5
# 10    28           3
# 40    29           1
# 13    30           2
# 18    31           2
# 39    32           1
# 29    33           2
# 34    34           1
# 11    35           3
# 23    37           2
# 27    38           2
# 35    40           1
# 5     41           3
# 37    42           1
# 42    43           1
# 20    45           2
# 22    46           2
# 9     47           3
# 30    48           2
# 12    49           2
# 28    50           2
# 45    51           1
# 15    52           2
# 24    53           2
# 41    54           1
# 31    55           1
# 6     56           3
# 33    57           1
# 4     58           4
# 3     59           5
# 17    60           2
# 36    62           1
# 1     63           6
# 43    65           1
# 26    66           2
# 7     67           3
# 19    68           2
# 0     69           6
# 8     70           3

# %% [markdown]
# Calcular la frecuencia relativa

# %%
tabla_frecuencias["Frec Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 21    18           2           0.02
# 16    19           2           0.02
# 38    21           1           0.01
# 44    22           1           0.01
# 25    23           2           0.02
# 14    24           2           0.02
# 32    25           1           0.01
# 2     26           5           0.05
# 10    28           3           0.03
# 40    29           1           0.01
# 13    30           2           0.02
# 18    31           2           0.02
# 39    32           1           0.01
# 29    33           2           0.02
# 34    34           1           0.01
# 11    35           3           0.03
# 23    37           2           0.02
# 27    38           2           0.02
# 35    40           1           0.01
# 5     41           3           0.03
# 37    42           1           0.01
# 42    43           1           0.01
# 20    45           2           0.02
# 22    46           2           0.02
# 9     47           3           0.03
# 30    48           2           0.02
# 12    49           2           0.02
# 28    50           2           0.02
# 45    51           1           0.01
# 15    52           2           0.02
# 24    53           2           0.02
# 41    54           1           0.01
# 31    55           1           0.01
# 6     56           3           0.03
# 33    57           1           0.01
# 4     58           4           0.04
# 3     59           5           0.05
# 17    60           2           0.02
# 36    62           1           0.01
# 1     63           6           0.06
# 43    65           1           0.01
# 26    66           2           0.02
# 7     67           3           0.03
# 19    68           2           0.02
# 0     69           6           0.06
# 8     70           3           0.03

# %% [markdown]
# Calcular la frecuencia porcentual

# %%
tabla_frecuencias["Frec Porcentual"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 21    18           2           0.02              2.0
# 16    19           2           0.02              2.0
# 38    21           1           0.01              1.0
# 44    22           1           0.01              1.0
# 25    23           2           0.02              2.0
# 14    24           2           0.02              2.0
# 32    25           1           0.01              1.0
# 2     26           5           0.05              5.0
# 10    28           3           0.03              3.0
# 40    29           1           0.01              1.0
# 13    30           2           0.02              2.0
# 18    31           2           0.02              2.0
# 39    32           1           0.01              1.0
# 29    33           2           0.02              2.0
# 34    34           1           0.01              1.0
# 11    35           3           0.03              3.0
# 23    37           2           0.02              2.0
# 27    38           2           0.02              2.0
# 35    40           1           0.01              1.0
# 5     41           3           0.03              3.0
# 37    42           1           0.01              1.0
# 42    43           1           0.01              1.0
# 20    45           2           0.02              2.0
# 22    46           2           0.02              2.0
# 9     47           3           0.03              3.0
# 30    48           2           0.02              2.0
# 12    49           2           0.02              2.0
# 28    50           2           0.02              2.0
# 45    51           1           0.01              1.0
# 15    52           2           0.02              2.0
# 24    53           2           0.02              2.0
# 41    54           1           0.01              1.0
# 31    55           1           0.01              1.0
# 6     56           3           0.03              3.0
# 33    57           1           0.01              1.0
# 4     58           4           0.04              4.0
# 3     59           5           0.05              5.0
# 17    60           2           0.02              2.0
# 36    62           1           0.01              1.0
# 1     63           6           0.06              6.0
# 43    65           1           0.01              1.0
# 26    66           2           0.02              2.0
# 7     67           3           0.03              3.0
# 19    68           2           0.02              2.0
# 0     69           6           0.06              6.0
# 8     70           3           0.03              3.0

# %% [markdown]
# Calcular la frecuencia acumulada

# %%
tabla_frecuencias["Frecuencia Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frecuencia Acumulada
# 21    18           2           0.02              2.0                     2
# 16    19           2           0.02              2.0                     4
# 38    21           1           0.01              1.0                     5
# 44    22           1           0.01              1.0                     6
# 25    23           2           0.02              2.0                     8
# 14    24           2           0.02              2.0                    10
# 32    25           1           0.01              1.0                    11
# 2     26           5           0.05              5.0                    16
# 10    28           3           0.03              3.0                    19
# 40    29           1           0.01              1.0                    20
# 13    30           2           0.02              2.0                    22
# 18    31           2           0.02              2.0                    24
# 39    32           1           0.01              1.0                    25
# 29    33           2           0.02              2.0                    27
# 34    34           1           0.01              1.0                    28
# 11    35           3           0.03              3.0                    31
# 23    37           2           0.02              2.0                    33
# 27    38           2           0.02              2.0                    35
# 35    40           1           0.01              1.0                    36
# 5     41           3           0.03              3.0                    39
# 37    42           1           0.01              1.0                    40
# 42    43           1           0.01              1.0                    41
# 20    45           2           0.02              2.0                    43
# 22    46           2           0.02              2.0                    45
# 9     47           3           0.03              3.0                    48
# 30    48           2           0.02              2.0                    50
# 12    49           2           0.02              2.0                    52
# 28    50           2           0.02              2.0                    54
# 45    51           1           0.01              1.0                    55
# 15    52           2           0.02              2.0                    57
# 24    53           2           0.02              2.0                    59
# 41    54           1           0.01              1.0                    60
# 31    55           1           0.01              1.0                    61
# 6     56           3           0.03              3.0                    64
# 33    57           1           0.01              1.0                    65
# 4     58           4           0.04              4.0                    69
# 3     59           5           0.05              5.0                    74
# 17    60           2           0.02              2.0                    76
# 36    62           1           0.01              1.0                    77
# 1     63           6           0.06              6.0                    83
# 43    65           1           0.01              1.0                    84
# 26    66           2           0.02              2.0                    86
# 7     67           3           0.03              3.0                    89
# 19    68           2           0.02              2.0                    91
# 0     69           6           0.06              6.0                    97
# 8     70           3           0.03              3.0                   100

# %%
# importamos la libreria math de funciones matematicas
import math
import matplotlib.pyplot as plt

# %%
# volvemos a usar la lista edades
print(edades)
# Out:
# [30, 69, 68, 45, 41, 25, 55, 28, 57, 31, 49, 56, 60, 35, 34, 69, 50, 33, 53, 70, 26, 18, 42, 59, 37, 67, 56, 46, 31, 62, 35, 45, 40, 26, 69, 30, 50, 37, 70, 18, 69, 21, 60, 47, 59, 29, 66, 28, 59, 41, 48, 53, 38, 23, 54, 48, 26, 67, 66, 58, 32, 63, 49, 58, 65, 19, 56, 43, 58, 63, 63, 59, 24, 22, 38, 23, 51, 63, 68, 41, 47, 19, 67, 63, 58, 24, 33, 26, 59, 52, 28, 70, 47, 69, 46, 63, 26, 52, 69, 35]

# %%
#crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     30
# 1     69
# 2     68
# 3     45
# 4     41
# ..   ...
# 95    63
# 96    26
# 97    52
# 98    69
# 99    35
#
# [100 rows x 1 columns]

# %%
# calcular el numero de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(n))
print("Valor de n =", n , "\nNumero de intervalos = ", k)
# Out:
# Valor de n = 100
# Numero de intervalos =  7

# %%
# crear la tabla de frecuencia

tabla_frecuencias = pd.cut(df['Edad'], bins = k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    23
# 1  (55.143, 62.571]    16
# 2  (25.429, 32.857]    14
# 3  (47.714, 55.143]    13
# 4  (40.286, 47.714]    12
# 5  (32.857, 40.286]    11
# 6  (17.947, 25.429]    11

# %%
# ordenar la tabla de frecuencias por el intervalo
tabla_frecuencias = tabla_frecuencias.sort_values(by = 'Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 6  (17.947, 25.429]    11
# 2  (25.429, 32.857]    14
# 5  (32.857, 40.286]    11
# 4  (40.286, 47.714]    12
# 3  (47.714, 55.143]    13
# 1  (55.143, 62.571]    16
# 0    (62.571, 70.0]    23

# %%
# generar columnas siguientes
tabla_frecuencias['Frec Rel'] = tabla_frecuencias['Frec'] / n
tabla_frecuencias['Frec Porc'] = tabla_frecuencias['Frec'] / n * 100
tabla_frecuencias['Frec Acum'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac'] = tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['Frec Porc Ac'] = tabla_frecuencias['Frec Porc'].cumsum()

# mostrar la tabla de frecuencia
print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Acum  Frec Rel Ac  \
# 6  (17.947, 25.429]    11      0.11       11.0         11         0.11
# 2  (25.429, 32.857]    14      0.14       14.0         25         0.25
# 5  (32.857, 40.286]    11      0.11       11.0         36         0.36
# 4  (40.286, 47.714]    12      0.12       12.0         48         0.48
# 3  (47.714, 55.143]    13      0.13       13.0         61         0.61
# 1  (55.143, 62.571]    16      0.16       16.0         77         0.77
# 0    (62.571, 70.0]    23      0.23       23.0        100         1.00
#
#    Frec Porc Ac
# 6          11.0
# 2          25.0
# 5          36.0
# 4          48.0
# 3          61.0
# 1          77.0
# 0         100.0

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=k, alpha=0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
