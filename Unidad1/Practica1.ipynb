# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Flores-Hernandez/Probabilidad/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
#
# # **Unidad 1**
#
# ## Practica 1: **Estadistica descriptiva e Histogramas**
#
# Docente: José Gabriel Rodriguez Rivas
#
# Alumno: Vanessa Mariam Flores Hernández

# %%
from statistics import *

# %%
#Lista de calificaciones del grupo a de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
type(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
# Sacar la medida de las calificaciones con una formula
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#utilizar la funcion  mean que esta en la libreria statistics para sacar
#el promedio

promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
#deterinar el valor de la mediana con la funcion median

mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
# determinar el valor de la moda con la funcion mode

moda = mode(grupoa)
print(grupoa)
print(moda)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 70

# %%
# en caso de que exista mas de una moda, se puede emplear la funcion multimode para sacar las
# multiples modas que puedan existir

moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
#definimos una variable llamada tiempos100mts de tipo lista, que contiene los tiempos
# que tardaron los 10 alumnos para correr los 100 metros
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

#desplegamos los valores de la lista
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
# usamos la funcion mean para determinar el tiempo promedio de la lista de valores

print("el tiempo pronmmedio de los corredores es= ",mean(tiempos100mts) )
# Out:
# el tiempo pronmmedio de los corredores es=  17.322

# %%
# definimos una variable llamada moda para calcular la moda de las lista con la funcion mode

moda = mode(tiempos100mts)
print("la moda de los tiempos es= ", moda)
# Out:
# la moda de los tiempos es=  15.1

# %%
multimodas = multimode(tiempos100mts)
print("la moda de los tiempos es= ", multimodas)
# Out:
# la moda de los tiempos es=  [15.1, 17.2]

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [97.92, 97.92, 51.91, 82.76, 91.46, 62.45, 75.57, 85.95, 57.24, 67.52, 50.33, 71.49, 97.58, 91.86, 73.2, 54.64, 61.95, 69.15, 65.92, 77.67, 88.93, 75.73, 87.37, 68.62, 83.67, 72.95, 86.08, 65.55, 96.92, 99.69, 58.28, 81.25, 81.76, 66.31, 52.74, 73.18, 58.07, 72.85, 81.22, 72.12, 51.12, 95.87, 69.65, 73.82, 63.97, 69.6, 57.59, 61.92, 57.4, 88.63, 72.81, 72.61, 87.12, 94.5, 52.48, 53.92, 64.73, 51.91, 67.35, 92.59, 76.85, 95.43, 99.09, 99.72, 83.58, 97.07, 61.73, 84.95, 76.58, 55.27, 51.04, 61.43, 84.17, 59.34, 95.32, 54.99, 69.68, 51.26, 99.28, 73.67, 83.99, 87.99, 53.7, 86.74, 64.91, 53.76, 71.23, 53.68, 50.11, 93.34, 56.46, 74.39, 80.76, 92.26, 93.09, 73.83, 87.6, 76.55, 61.29, 50.35]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round( random.uniform(70, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [86.17, 74.03, 97.05, 72.28, 85.27, 79.37, 72.53, 76.26, 95.97, 81.31, 71.36, 93.23, 99.31, 72.27, 97.68, 78.88, 76.95, 81.58, 71.1, 85.53, 97.62, 89.57, 83.0, 71.75, 83.5, 82.76, 82.12, 71.82, 96.7, 82.28, 79.51, 70.12, 92.11, 94.44, 77.12, 85.92, 75.7, 89.04, 94.74, 99.62, 79.91, 95.25, 86.01, 85.88, 92.59, 83.86, 85.74, 95.25, 94.3, 89.63, 96.44, 76.43, 73.56, 78.17, 82.88, 87.87, 96.88, 79.97, 76.79, 97.82, 92.65, 82.85, 72.65, 89.48, 84.5, 93.75, 97.71, 96.49, 82.78, 83.05, 89.48, 71.68, 92.71, 91.29, 85.49, 80.89, 85.08, 93.57, 90.36, 83.71, 90.79, 92.26, 86.38, 97.41, 89.53, 96.14, 97.56, 78.96, 80.06, 72.59, 85.48, 95.62, 90.65, 78.44, 84.72, 88.14, 80.13, 88.64, 75.33, 99.61]

# %%
# libreria de phyton para garficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la Fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("valores de la fabrica 1")
print("la medida es= ", media1)
print("la mediana es= ", mediana1)
print("la moda es= ", moda1)
# Out:
# valores de la fabrica 1
# la medida es=  73.8385
# la mediana es=  73.065
# la moda es=  97.92

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("valores de la fabrica 2")
print("la medida es= ", media2)
print("la mediana es= ", mediana2)
print("la moda es= ", moda2)
# Out:
# valores de la fabrica 2
# la medida es=  85.7141
# la mediana es=  85.50999999999999
# la moda es=  95.25
