# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Flores-Hernandez/Probabilidad/blob/main/Unidad1/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
#
# ## Unidad 1
#
# ### **Practica 2. Máximo, mínimo, rango y dispersión de datos.**
#
# ### Facilitador: *Dr. Jose Gabriel Rodriguez Rivera*
#
# ### Alumno: Vanessa Mariam Flores Hernandez

# %%
import random
import matplotlib.pyplot as plt  #libreria para graficar
from statistics import *

# %%
# Generamos 100 numeros aleatorios que representan la produccion en metros de tela de 100 dias
fabrica1 = []
for i in range(100):
  numero_aleatorio = round ( random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [82.12, 57.81, 87.22, 67.55, 87.13, 56.58, 84.65, 93.19, 58.58, 65.26, 75.55, 64.27, 93.69, 64.03, 95.86, 52.6, 72.35, 61.17, 66.69, 86.9, 97.47, 99.06, 65.37, 63.25, 64.91, 85.96, 90.68, 63.78, 64.64, 73.2, 57.0, 96.31, 65.07, 75.96, 80.37, 59.34, 65.46, 99.91, 99.52, 73.83, 98.09, 70.47, 66.75, 67.65, 64.56, 60.93, 55.6, 85.94, 89.73, 87.46, 99.33, 59.34, 75.22, 64.09, 96.68, 75.98, 67.14, 67.32, 61.49, 55.88, 88.5, 97.14, 91.46, 85.23, 55.58, 56.42, 95.68, 89.96, 69.69, 78.27, 52.62, 76.44, 53.72, 66.13, 57.08, 56.09, 91.2, 58.64, 86.66, 92.23, 86.66, 84.13, 50.27, 90.46, 51.09, 55.43, 57.99, 62.82, 86.73, 82.75, 55.56, 52.57, 77.27, 61.7, 84.37, 93.52, 73.38, 86.74, 82.03, 86.62]

# %%
fabrica2 = []        #Rnago de numero aleatorios entre 70 y 100
for i in range(100):
  numero_aleatorio2 = round ( random.uniform(70,100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [94.75, 75.77, 97.74, 93.62, 73.37, 92.79, 92.44, 94.21, 87.21, 85.26, 93.89, 98.82, 88.28, 91.46, 91.22, 96.57, 75.27, 80.57, 98.31, 72.03, 91.9, 80.4, 93.1, 90.57, 75.8, 70.87, 85.01, 74.81, 91.52, 97.21, 81.11, 87.24, 95.02, 96.72, 94.69, 77.82, 94.17, 95.85, 80.15, 75.51, 95.49, 99.04, 86.26, 78.48, 81.64, 89.14, 92.29, 88.26, 94.65, 99.21, 90.05, 75.77, 87.99, 88.77, 89.51, 81.25, 94.83, 74.96, 90.33, 94.42, 84.79, 79.83, 83.17, 74.96, 90.76, 79.73, 89.02, 94.19, 81.8, 92.49, 91.23, 80.54, 72.92, 95.88, 75.39, 92.77, 95.03, 96.74, 77.3, 79.04, 78.2, 88.38, 81.81, 82.83, 98.0, 96.85, 80.59, 70.31, 95.35, 95.25, 85.21, 92.35, 77.0, 88.39, 82.53, 71.3, 78.26, 78.24, 82.69, 88.57]

# %% [markdown]
# Maximo, minimo y rango

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1= mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print ("Estadistica descriptiva de la Fabrica 1 \n", "Media = ", media1,
       "\n Mediana = ", mediana1, "\n Moda = ", moda1, "\n Maximo= ", maximo1,
       "\n Minimo =", minimo1, "\n Rango = ", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media =  74.4477
#  Mediana =  73.28999999999999
#  Moda =  59.34
#  Maximo=  99.91
#  Minimo = 50.27
#  Rango =  49.63999999999999
# 14.830218253432564

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2= mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print ("Estadistica descriptiva de la Fabrica 2 \n", "Media = ", media2,
       "\n Mediana = ", mediana2, "\n Moda = ", moda2, "\n Maximo= ", maximo2,
       "\n Minimo =", minimo2, "\n Rango = ", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media =  86.7508
#  Mediana =  88.38499999999999
#  Moda =  75.77
#  Maximo=  99.21
#  Minimo = 70.31
#  Rango =  28.89999999999999
# 8.116030860543404

# %% [markdown]
# Dispersion de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.830218253432564

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 8.116030860543404

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle= 'dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle= 'dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle= 'dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle= 'dashed',
            linewidth=2, label=f'Desv . Estándar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle= 'dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle= 'dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle= 'dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle= 'dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica1, color='black', linestyle= 'dashed',
            linewidth=2, label=f'Desv . Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle= 'dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns
# la densidad grafica es una forma de visualizar la distribucion de datos en
# un intervalo o periodo de tiempo continuo.
# se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones mas suaves al reducir el ruido.
# una curva de densidad muestra la ubicacion de la media y la median en una distribucion
sns.histplot( x= fabrica1, kde = True, kde_kws= {'bw_adjust': 0.5}, bins=10)
# Out:
# <Axes: ylabel='Count'>
